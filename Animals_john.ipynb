# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnHenin/Animals/blob/main/Animals_john.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
path = '/content/Table_40.csv'
import pandas as pd
#Can write the path directly as well
df = pd.read_csv(path)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        S. No.             State/U.T  Milch Cows - Crossbred - 2007  \
# 0           1        Andhra Pradesh                         828.11
# 1           2     Arunachal Pradesh                           5.55
# 2           3                 Assam                         152.81
# 3           4                 Bihar                         836.46
# 4           5          Chhattisgarh                          58.80
# 5           6                   Goa                           8.30
# 6           7               Gujarat                         524.98
# 7           8               Haryana                         267.81
# 8           9      Himachal Pradesh                         409.26
# 9          10       Jammu & Kashmir                         677.65
# 10         11             Jharkhand                          67.26
# 11         12             Karnataka                        1258.92
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 35
plt.figure(figsize = (77, 47))
#see the spelling of arrange
ind = np.arange(N)
width = 0.50
xval = df['Milch Cows - Crossbred - 2007'].head(35)

bar1 = plt.bar(ind, xval, width, color = 'r')
yval = df['Milch Cows - Crossbred - 2012'].head(35)
bar2 = plt.bar(ind + width, yval, width, color = 'b')

#comparitive charts should always have legends

plt.xlabel('State/U.T')
plt.ylabel('Milch Cows - Crossbred')
plt.xticks(ind + width, df['State/U.T'].head(35))
plt.legend((bar1, bar2),('Milch Cows - Crossbred - 2007', 'Milch Cows - Crossbred - 2012'))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(47,15))
plt.plot(df['State/U.T'].head(35), df['Milch Cows - Crossbred - % Change'].head(35),marker = 'o', color = 'orange')

# %%
plt.figure(figsize=(65,45))
plt.bar(df['State/U.T'].head(35), df['Milch Cows - Indigenous - 2007'].head(35))
plt.bar(df['State/U.T'].head(35), df['Milch Cows - Indigenous - 2012'].head(35), bottom = df['Milch Cows - Indigenous - 2007'].head(35))
# Out:
# <BarContainer object of 35 artists>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(47,15))
plt.plot(df['State/U.T'].head(35), df['Milch Cows - Indigenous - % Change'].head(35),marker = 'o', color = 'cyan')

# %%
import numpy as np
N = 35
plt.figure(figsize = (65, 45))
#see the spelling of arrange
ind = np.arange(N)
width = 0.5 
xval = df['Milch Buffaloes - 2007'].head(35)

bar1 = plt.bar(ind, xval, width, color = 'r')
yval = df['Milch Buffaloes - 2012'].head(35)
bar2 = plt.bar(ind + width, yval, width, color = 'pink')

#comparitive charts should always have legends

plt.xlabel('State/U.T')
plt.ylabel('Milch Buffaloes - 2007')
plt.xticks(ind + width, df['State/U.T'].head(35))
plt.legend((bar1, bar2),('Milch Buffaloes - 2007', 'Milch Buffaloes - 2012'))

# %%
plt.boxplot(df['Milch Buffaloes - % Change']);

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #Data Visualization 
import seaborn as sns

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
path = '/content/Table_40.csv'
dataset = pd.read_csv(path)
dataset
# Out:
# Mounted at /content/drive
#        S. No.             State/U.T  Milch Cows - Crossbred - 2007  \
# 0           1        Andhra Pradesh                         828.11
# 1           2     Arunachal Pradesh                           5.55
# 2           3                 Assam                         152.81
# 3           4                 Bihar                         836.46
# 4           5          Chhattisgarh                          58.80
# 5           6                   Goa                           8.30
# 6           7               Gujarat                         524.98
# 7           8               Haryana                         267.81
# 8           9      Himachal Pradesh                         409.26
# 9          10       Jammu & Kashmir                         677.65
# 10         11             Jharkhand                          67.26
# 11         12             Karnataka                        1258.92
# 12         13                Kerala                         745.19
# ...

# %%
X= dataset.iloc[:, [2,10]].values

# %%
from sklearn.cluster import KMeans
wcss=[]

for i in range(1,35):
    kmeans = KMeans(n_clusters= i, init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,35), wcss)
plt.title('The Elbow Method')
plt.xlabel('no of clusters')
plt.ylabel('wcss')
plt.show()

# %%
kmeansmodel = KMeans(n_clusters= 6, init='k-means++', random_state=0)
y_kmeans= kmeansmodel.fit_predict(X)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s =300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of animals')
plt.xlabel('Milch cows')
plt.ylabel('State/U.T')
plt.legend()
plt.show()
